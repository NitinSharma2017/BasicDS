# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.image as mpimg

# %%
m = [[0,0,0.5,0,5],
     [0,0,-1,0.7,5],
     [0,-2.8,0,0,5.5]
    ]

plt.imshow(m)

# %%
m.describe()

# %%
np.sin(np.array((0., 30., 45., 60., 90.)) * np.pi / 180. )

# %%
x = np.sin(np.array((0., 30., 45., 60., 90.)) * np.pi / 180. ) + np.sin(np.array((0., 30., 45., 60., 90.)) * np.pi / 90. )
x

# %%
plt.imshow(x)

# %%
img=mpimg.imread('img2.png')
img
# Out:
# array([[[0.5764706 , 0.78039217, 1.        , 1.        ],
#         [0.5647059 , 0.78039217, 1.        , 1.        ],
#         [0.5647059 , 0.78039217, 1.        , 1.        ],
#         ...,
#         [0.50980395, 0.7411765 , 1.        , 1.        ],
#         [0.49411765, 0.74509805, 0.99607843, 1.        ],
#         [0.49019608, 0.75686276, 0.99607843, 1.        ]],
#
#        [[0.5803922 , 0.78431374, 1.        , 1.        ],
#         [0.57254905, 0.7764706 , 1.        , 1.        ],
#         [0.5647059 , 0.78039217, 1.        , 1.        ],
#         ...,
#         [0.5019608 , 0.7607843 , 1.        , 1.        ],
#         [0.4862745 , 0.7607843 , 0.99607843, 1.        ],
#         [0.4862745 , 0.7607843 , 0.99607843, 1.        ]],
#
#        [[0.5686275 , 0.78431374, 1.        , 1.        ],
#         [0.5647059 , 0.78039217, 1.        , 1.        ],
#         [0.5647059 , 0.78039217, 1.        , 1.        ],
#         ...,
#         [0.4862745 , 0.7607843 , 0.99607843, 1.        ],
#         [0.49019608, 0.75686276, 0.99607843, 1.        ],
#         [0.5019608 , 0.7607843 , 1.        , 1.        ]],
#
#        ...,
#
#        [[0.54509807, 0.39215687, 0.        , 1.        ],
#         [0.29803923, 0.22352941, 0.00392157, 1.        ],
#         [0.21568628, 0.20392157, 0.        , 1.        ],
#         ...,
#         [0.8235294 , 0.6039216 , 0.        , 1.        ],
#         [0.8156863 , 0.5921569 , 0.        , 1.        ],
#         [0.81960785, 0.58431375, 0.        , 1.        ]],
#
#        [[0.6039216 , 0.43137255, 0.00392157, 1.        ],
#         [0.35686275, 0.25882354, 0.        , 1.        ],
#         [0.23529412, 0.20784314, 0.00392157, 1.        ],
#         ...,
#         [0.827451  , 0.59607846, 0.        , 1.        ],
#         [0.827451  , 0.5921569 , 0.00392157, 1.        ],
#         [0.83137256, 0.5921569 , 0.        , 1.        ]],
#
#        [[0.6627451 , 0.47058824, 0.00392157, 1.        ],
#         [0.44313726, 0.3019608 , 0.        , 1.        ],
#         [0.26666668, 0.20392157, 0.01176471, 1.        ],
#         ...,
#         [0.827451  , 0.5882353 , 0.        , 1.        ],
#         [0.827451  , 0.5882353 , 0.        , 1.        ],
#         [0.83137256, 0.5921569 , 0.        , 1.        ]]], dtype=float32)

# %%
plt.imshow(img)

# %%
lum_img = img[:,:,0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()
